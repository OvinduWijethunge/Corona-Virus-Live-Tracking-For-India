# %%
import pandas as pd

# %%
df = pd.read_json('https://www.mohfw.gov.in/data/datanew.json')
df
# Out:
#       sno                                state_name  active  positive  \
# 0       2               Andaman and Nicobar Islands      23      4992
# 1       1                            Andhra Pradesh    1488    886694
# 2       3                         Arunachal Pradesh      37     16817
# 3       4                                     Assam    2482    216957
# 4       5                                     Bihar    2682    258513
# 5       6                                Chandigarh     137     20664
# 6       7                              Chhattisgarh    5308    295949
# 7       8  Dadra and Nagar Haveli and Daman and Diu      10      3394
# 8      10                                     Delhi    2060    633542
# 9      11                                       Goa     854     52782
# 10     12                                   Gujarat    5240    258264
# 11     13                                   Haryana    1585    266939
# ...
